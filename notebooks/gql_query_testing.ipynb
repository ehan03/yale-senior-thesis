# %%
import json
import requests

# %%
EVENTS_RECENT_GQL_QUERY = """
query EventsPromotionRecentQuery(
  $promotionSlug: String
  $dateLt: Date
  $dateGte: Date
  $after: String
  $first: Int
  $orderBy: String
) {
  promotion: promotionBySlug(slug: $promotionSlug) {
    ...EventsPromotionTabPanel_promotion_34GGrn
    id
  }
}

fragment EventCardList_events on EventNodeConnection {
  edges {
    node {
      id
      ...EventCard_event
    }
  }
}

fragment EventCard_event on EventNode {
  id
  name
  pk
  slug
  date
  venue
  city
  promotion {
    slug
    shortName
    id
  }
  ...EventPoster_event
}

fragment EventPoster_event on EventNode {
  name
  poster
  posterWide
  promotion {
    shortName
    logo
    id
  }
}

fragment EventsPromotionTabPanel_promotion_34GGrn on PromotionNode {
  ...PromotionEventCardListInfiniteScroll_promotion_34GGrn
}

fragment PromotionEventCardListInfiniteScroll_promotion_34GGrn on PromotionNode {
  events(first: $first, after: $after, date_Gte: $dateGte, date_Lt: $dateLt, orderBy: $orderBy) {
    ...EventCardList_events
    edges {
      node {
        id
        __typename
      }
      cursor
    }
    pageInfo {
      hasNextPage
      endCursor
    }
  }
}
"""

url = "https://api.fightinsider.io/gql"
headers = {
    "X-Requested-With": "XMLHttpRequest",
    "Content-Type": "application/json",
}

payload = json.dumps(
    {
        "query": EVENTS_RECENT_GQL_QUERY,
        "variables": {
            "promotionSlug": "ufc",
            "dateLt": "2024-12-31",
            "after": "",
            "first": 100,
            "orderBy": "-date",
        },
    }
)
response = requests.post(url=url, headers=headers, data=payload)
json_resp = response.json()
events = json_resp["data"]["promotion"]["events"]
edges = events["edges"]
event_pks = [edge["node"]["pk"] for edge in edges]

print(event_pks)
# Out:
# [5939, 5934, 5938, 5929, 5922, 5919, 5611, 5917, 5898, 5834, 5581, 5414, 5835, 5849, 5590, 5761, 5550, 5766, 5762, 5589, 5434, 5486, 5580, 5575, 5513, 5514, 5515, 5475, 5477, 5416, 5424, 5382, 5394, 5402, 5356, 5318, 5362, 5355, 5358, 5347, 5306, 5293, 4779, 5281, 5251, 4778, 5098, 4777, 4655, 5107, 4776, 4775, 4774, 4749, 4802, 4755, 4727, 4738, 4751, 4744, 4671, 4702, 4634, 4696, 4668, 4666, 4654, 4643, 4627, 4615, 4594, 4592, 4579, 4580, 4556, 4501, 4483, 4486, 4450, 4469, 4460, 4438, 4441, 4382, 4426, 4336, 4335, 4334, 4333, 4332, 4331, 4330, 3934, 4318, 4257, 4279, 4051, 4032, 4047, 4048]

# %%
EVENT_FIGHTS_QUERY = """
query EventFightsQuery(
  $eventPk: Int
) {
  event: eventByPk(pk: $eventPk) {
    pk
    slug
    fights {
      ...EventTabPanelFights_fights
    }
    id
  }
}

fragment EventTabPanelFights_fights on FightNodeConnection {
  edges {
    node {
      id
    }
  }
  ...FightTable_fights
  ...FightCardList_fights
}

fragment FightCardList_fights on FightNodeConnection {
  edges {
    node {
      ...FightCard_fight
      id
    }
  }
}

fragment FightCard_fight on FightNode {
  id
  pk
  fighter1 {
    id
    firstName
    lastName
    slug
  }
  fighter2 {
    id
    firstName
    lastName
    slug
  }
  fighterWinner {
    id
  }
  order
  weightClass {
    weightClass
    weight
    id
  }
  fighter1Odds
  fighter2Odds
  fightType
  methodOfVictory1
  methodOfVictory2
  round
  duration
  slug
}

fragment FightTable_fights on FightNodeConnection {
  edges {
    node {
      id
      fighter1 {
        id
        pk
        firstName
        lastName
        slug
        ...FighterFlag_fighter
      }
      fighter2 {
        id
        pk
        firstName
        lastName
        slug
        ...FighterFlag_fighter
      }
      fighterWinner {
        id
        pk
        firstName
        lastName
        slug
        ...FighterFlag_fighter
      }
      order
      weightClass {
        weightClass
        weight
        id
      }
      isCancelled
      fightType
      methodOfVictory1
      methodOfVictory2
      round
      duration
      slug
    }
  }
}

fragment FighterFlag_fighter on FighterNode {
  nationality
}
"""

payload = json.dumps(
    {
        "query": EVENT_FIGHTS_QUERY,
        "variables": {
        "eventPk": "5939"
        },
    }
)
response = requests.post(url=url, headers=headers, data=payload)
json_resp = response.json()
json_resp
# Out:
# {'data': {'event': {'pk': 5939,
#    'slug': 'ufc-fight-night-covington-vs-buckley',
#    'fights': {'edges': [{'node': {'id': 'RmlnaHROb2RlOjU3NjE2',
#        'fighter1': {'id': 'RmlnaHRlck5vZGU6NTgyNg==',
#         'pk': 5826,
#         'firstName': 'Colby',
#         'lastName': 'Covington',
#         'slug': 'colby-covington-5826',
#         'nationality': 'United States'},
#        'fighter2': {'id': 'RmlnaHRlck5vZGU6ODk5Mw==',
#         'pk': 8993,
#         'firstName': 'Joaquin',
#         'lastName': 'Buckley',
#         'slug': 'joaquin-buckley-8993',
#         'nationality': 'United States'},
#        'fighterWinner': {'id': 'RmlnaHRlck5vZGU6ODk5Mw==',
#         'pk': 8993,
#         'firstName': 'Joaquin',
#         'lastName': 'Buckley',
#         'slug': 'joaquin-buckley-8993',
#         'nationality': 'United States'},
#        'order': 1,
#        'weightClass': {'weightClass': 'Welterweight',
#         'weight': 170,
#         'id': 'V2VpZ2h0Q2xhc3NOb2RlOjc='},
#        'isCancelled': False,
#        'fightType': 'ME',
#        'methodOfVictory1': 'KO/TKO',
#        'methodOfVictory2': 'Doctor Stoppage (Cut Above Eye)',
#        'round': 3,
#        'duration': '4:42',
#        'slug': 'colby-covington-vs-joaquin-buckley-57616',
#        'pk': 57616,
#        'fighter1Odds': 179,
#        'fighter2Odds': -209}},
#      {'node': {'id': 'RmlnaHROb2RlOjU2OTcw',
#        'fighter1': {'id': 'RmlnaHRlck5vZGU6MTM1MA==',
#         'pk': 1350,
#         'firstName': 'Cub',
#         'lastName': 'Swanson',
#         'slug': 'cub-swanson-1350',
#         'nationality': 'United States'},
#        'fighter2': {'id': 'RmlnaHRlck5vZGU6MTQ5MTk=',
#         'pk': 14919,
#         'firstName': 'Billy',
#         'lastName': 'Quarantillo',
#         'slug': 'billy-quarantillo-14919',
#         'nationality': 'United States'},
#        'fighterWinner': {'id': 'RmlnaHRlck5vZGU6MTM1MA==',
#         'pk': 1350,
#         'firstName': 'Cub',
#         'lastName': 'Swanson',
#         'slug': 'cub-swanson-1350',
#         'nationality': 'United States'},
#        'order': 2,
#        'weightClass': {'weightClass': 'Featherweight',
#         'weight': 145,
#         'id': 'V2VpZ2h0Q2xhc3NOb2RlOjU='},
#        'isCancelled': False,
#        'fightType': 'CO',
#        'methodOfVictory1': 'KO',
#        'methodOfVictory2': 'Punch',
#        'round': 3,
#        'duration': '1:36',
#        'slug': 'cub-swanson-vs-billy-quarantillo-56970',
#        'pk': 56970,
#        'fighter1Odds': 136,
#        'fighter2Odds': -156}},
#      {'node': {'id': 'RmlnaHROb2RlOjU2NzY3',
#        'fighter1': {'id': 'RmlnaHRlck5vZGU6NzczMQ==',
#         'pk': 7731,
#         'firstName': 'Manel',
#         'lastName': 'Kape',
#         'slug': 'manel-kape-7731',
#         'nationality': 'Portugal'},
#        'fighter2': {'id': 'RmlnaHRlck5vZGU6MTcxNDI=',
#         'pk': 17142,
#         'firstName': 'Bruno',
#         'lastName': 'Silva',
#         'slug': 'bruno-silva-17142',
#         'nationality': 'Brazil'},
#        'fighterWinner': {'id': 'RmlnaHRlck5vZGU6NzczMQ==',
#         'pk': 7731,
#         'firstName': 'Manel',
#         'lastName': 'Kape',
#         'slug': 'manel-kape-7731',
#         'nationality': 'Portugal'},
#        'order': 3,
#        'weightClass': {'weightClass': 'Flyweight',
#         'weight': 125,
#         'id': 'V2VpZ2h0Q2xhc3NOb2RlOjM='},
#        'isCancelled': False,
#        'fightType': 'MC',
#        'methodOfVictory1': 'TKO',
#        'methodOfVictory2': 'Body Kick and Punches',
#        'round': 3,
#        'duration': '1:57',
#        'slug': 'manel-kape-vs-bruno-silva-56767',
#        'pk': 56767,
#        'fighter1Odds': -430,
#        'fighter2Odds': 330}},
#      {'node': {'id': 'RmlnaHROb2RlOjU2MTA4',
#        'fighter1': {'id': 'RmlnaHRlck5vZGU6Mzk=',
#         'pk': 39,
#         'firstName': 'Dustin',
#         'lastName': 'Jacoby',
#         'slug': 'dustin-jacoby-39',
#         'nationality': 'United States'},
#        'fighter2': {'id': 'RmlnaHRlck5vZGU6NDA3NjA=',
#         'pk': 40760,
#         'firstName': 'Vitor',
#         'lastName': 'Petrino',
#         'slug': 'vitor-petrino-40760',
#         'nationality': 'Brazil'},
#        'fighterWinner': {'id': 'RmlnaHRlck5vZGU6Mzk=',
#         'pk': 39,
#         'firstName': 'Dustin',
#         'lastName': 'Jacoby',
#         'slug': 'dustin-jacoby-39',
#         'nationality': 'United States'},
#        'order': 4,
#        'weightClass': {'weightClass': 'Light Heavyweight',
#         'weight': 205,
#         'id': 'V2VpZ2h0Q2xhc3NOb2RlOjk='},
#        'isCancelled': False,
#        'fightType': 'MC',
#        'methodOfVictory1': 'KO',
#        'methodOfVictory2': 'Punch',
#        'round': 3,
#        'duration': '3:44',
#        'slug': 'dustin-jacoby-vs-vitor-petrino-56108',
#        'pk': 56108,
#        'fighter1Odds': 250,
#        'fighter2Odds': -300}},
#      {'node': {'id': 'RmlnaHROb2RlOjU3Mzcy',
#        'fighter1': {'id': 'RmlnaHRlck5vZGU6MzA4NQ==',
#         'pk': 3085,
#         'firstName': 'Adrian',
#         'lastName': 'Yanez',
#         'slug': 'adrian-yanez-3085',
#         'nationality': 'United States'},
#        'fighter2': {'id': 'RmlnaHRlck5vZGU6Mzg5MTU=',
#         'pk': 38915,
#         'firstName': 'Daniel',
#         'lastName': 'Marcos',
#         'slug': 'daniel-marcos-38915',
#         'nationality': 'Peru'},
#        'fighterWinner': {'id': 'RmlnaHRlck5vZGU6Mzg5MTU=',
#         'pk': 38915,
#         'firstName': 'Daniel',
#         'lastName': 'Marcos',
#         'slug': 'daniel-marcos-38915',
#         'nationality': 'Peru'},
#        'order': 5,
#        'weightClass': {'weightClass': 'Bantamweight',
#         'weight': 135,
#         'id': 'V2VpZ2h0Q2xhc3NOb2RlOjQ='},
#        'isCancelled': False,
#        'fightType': 'MC',
#        'methodOfVictory1': 'Decision',
#        'methodOfVictory2': 'Split',
#        'round': 3,
#        'duration': '5:00',
#        'slug': 'adrian-yanez-vs-daniel-marcos-57372',
#        'pk': 57372,
#        'fighter1Odds': 185,
#        'fighter2Odds': -220}},
#      {'node': {'id': 'RmlnaHROb2RlOjU2NTYw',
#        'fighter1': {'id': 'RmlnaHRlck5vZGU6NjQwODE=',
#         'pk': 64081,
#         'firstName': 'Navajo',
#         'lastName': 'Stirling',
#         'slug': 'navajo-stirling-64081',
#         'nationality': 'New Zealand'},
#        'fighter2': {'id': 'RmlnaHRlck5vZGU6Mjk4NDU=',
#         'pk': 29845,
#         'firstName': 'George',
#         'lastName': 'Tokkos',
#         'slug': 'george-tokkos-29845',
#         'nationality': 'London, England'},
#        'fighterWinner': {'id': 'RmlnaHRlck5vZGU6NjQwODE=',
#         'pk': 64081,
#         'firstName': 'Navajo',
#         'lastName': 'Stirling',
#         'slug': 'navajo-stirling-64081',
#         'nationality': 'New Zealand'},
#        'order': 6,
#        'weightClass': {'weightClass': 'Light Heavyweight',
#         'weight': 205,
#         'id': 'V2VpZ2h0Q2xhc3NOb2RlOjk='},
#        'isCancelled': False,
#        'fightType': 'MC',
#        'methodOfVictory1': 'Decision',
#        'methodOfVictory2': 'Unanimous',
#        'round': 3,
#        'duration': '5:00',
#        'slug': 'navajo-stirling-vs-george-tokkos-56560',
#        'pk': 56560,
#        'fighter1Odds': -1000,
#        'fighter2Odds': 700}},
#      {'node': {'id': 'RmlnaHROb2RlOjU3Mzcx',
#        'fighter1': {'id': 'RmlnaHRlck5vZGU6MjY1NzI=',
#         'pk': 26572,
#         'firstName': 'Ottman',
#         'lastName': 'Azaitar',
#         'slug': 'ottman-azaitar-26572',
#         'nationality': 'Cologne, Germany'},
#        'fighter2': {'id': 'RmlnaHRlck5vZGU6NTg1NA==',
#         'pk': 5854,
#         'firstName': 'Michael',
#         'lastName': 'Johnson',
#         'slug': 'michael-johnson-5854',
#         'nationality': 'St. Louis, Missouri, United States'},
#        'fighterWinner': {'id': 'RmlnaHRlck5vZGU6NTg1NA==',
#         'pk': 5854,
#         'firstName': 'Michael',
#         'lastName': 'Johnson',
#         'slug': 'michael-johnson-5854',
#         'nationality': 'St. Louis, Missouri, United States'},
#        'order': 7,
#        'weightClass': {'weightClass': 'Lightweight',
#         'weight': 155,
#         'id': 'V2VpZ2h0Q2xhc3NOb2RlOjY='},
#        'isCancelled': False,
#        'fightType': 'PL',
#        'methodOfVictory1': 'KO',
#        'methodOfVictory2': 'Punch',
#        'round': 2,
#        'duration': '2:03',
#        'slug': 'ottman-azaitar-vs-michael-johnson-57371',
#        'pk': 57371,
#        'fighter1Odds': 205,
#        'fighter2Odds': -240}},
#      {'node': {'id': 'RmlnaHROb2RlOjU3MjU0',
#        'fighter1': {'id': 'RmlnaHRlck5vZGU6MjY1Mjc=',
#         'pk': 26527,
#         'firstName': 'Joel',
#         'lastName': 'Alvarez',
#         'slug': 'joel-alvarez-26527',
#         'nationality': 'Spain'},
#        'fighter2': {'id': 'RmlnaHRlck5vZGU6MTE4Mjg=',
#         'pk': 11828,
#         'firstName': 'Drakkar',
#         'lastName': 'Klose',
#         'slug': 'drakkar-klose-11828',
#         'nationality': 'United States'},
#        'fighterWinner': {'id': 'RmlnaHRlck5vZGU6MjY1Mjc=',
#         'pk': 26527,
#         'firstName': 'Joel',
#         'lastName': 'Alvarez',
#         'slug': 'joel-alvarez-26527',
#         'nationality': 'Spain'},
#        'order': 8,
#        'weightClass': {'weightClass': 'Lightweight',
#         'weight': 155,
#         'id': 'V2VpZ2h0Q2xhc3NOb2RlOjY='},
#        'isCancelled': False,
#        'fightType': 'PL',
#        'methodOfVictory1': 'KO',
#        'methodOfVictory2': 'Flying Knee and Punches',
#        'round': 1,
#        'duration': '2:48',
#        'slug': 'joel-alvarez-vs-drakkar-klose-57254',
#        'pk': 57254,
#        'fighter1Odds': -510,
#        'fighter2Odds': 385}},
#      {'node': {'id': 'RmlnaHROb2RlOjU3Mjc3',
#        'fighter1': {'id': 'RmlnaHRlck5vZGU6MTE4MzM=',
#         'pk': 11833,
#         'firstName': 'Sean',
#         'lastName': 'Woodson',
#         'slug': 'sean-woodson-11833',
#         'nationality': 'Saint Louis'},
#        'fighter2': {'id': 'RmlnaHRlck5vZGU6MTc5MTE=',
#         'pk': 17911,
#         'firstName': 'Fernando',
#         'lastName': 'Padilla',
#         'slug': 'fernando-padilla-17911',
#         'nationality': 'Mexico'},
#        'fighterWinner': {'id': 'RmlnaHRlck5vZGU6MTE4MzM=',
#         'pk': 11833,
#         'firstName': 'Sean',
#         'lastName': 'Woodson',
#         'slug': 'sean-woodson-11833',
#         'nationality': 'Saint Louis'},
#        'order': 9,
#        'weightClass': {'weightClass': 'Featherweight',
#         'weight': 145,
#         'id': 'V2VpZ2h0Q2xhc3NOb2RlOjU='},
#        'isCancelled': False,
#        'fightType': 'PL',
#        'methodOfVictory1': 'TKO',
#        'methodOfVictory2': 'Punches',
#        'round': 1,
#        'duration': '4:58',
#        'slug': 'sean-woodson-vs-fernando-padilla-57277',
#        'pk': 57277,
#        'fighter1Odds': -145,
#        'fighter2Odds': 125}},
#      {'node': {'id': 'RmlnaHROb2RlOjU3NTA0',
#        'fighter1': {'id': 'RmlnaHRlck5vZGU6MzAxMQ==',
#         'pk': 3011,
#         'firstName': 'Miles',
#         'lastName': 'Johns',
#         'slug': 'miles-johns-3011',
#         'nationality': 'United States'},
#        'fighter2': {'id': 'RmlnaHRlck5vZGU6MzczOTQ=',
#         'pk': 37394,
#         'firstName': 'Felipe',
#         'lastName': 'Lima',
#         'slug': 'felipe-lima-37394',
#         'nationality': 'Brazil'},
#        'fighterWinner': {'id': 'RmlnaHRlck5vZGU6MzczOTQ=',
#         'pk': 37394,
#         'firstName': 'Felipe',
#         'lastName': 'Lima',
#         'slug': 'felipe-lima-37394',
#         'nationality': 'Brazil'},
#        'order': 10,
#        'weightClass': {'weightClass': 'Featherweight',
#         'weight': 145,
#         'id': 'V2VpZ2h0Q2xhc3NOb2RlOjU='},
#        'isCancelled': False,
#        'fightType': 'PL',
#        'methodOfVictory1': 'Decision',
#        'methodOfVictory2': 'Unanimous',
#        'round': 3,
#        'duration': '5:00',
#        'slug': 'miles-johns-vs-felipe-lima-57504',
#        'pk': 57504,
#        'fighter1Odds': 210,
#        'fighter2Odds': -250}},
#      {'node': {'id': 'RmlnaHROb2RlOjU3NDgx',
#        'fighter1': {'id': 'RmlnaHRlck5vZGU6MTIyMjY=',
#         'pk': 12226,
#         'firstName': 'Miranda',
#         'lastName': 'Maverick',
#         'slug': 'miranda-maverick-12226',
#         'nationality': 'United States'},
#        'fighter2': {'id': 'RmlnaHRlck5vZGU6MzUzNjY=',
#         'pk': 35366,
#         'firstName': 'Jamey-Lyn',
#         'lastName': 'Horth',
#         'slug': 'jamey-lyn-horth-35366',
#         'nationality': 'Canada'},
#        'fighterWinner': {'id': 'RmlnaHRlck5vZGU6MTIyMjY=',
#         'pk': 12226,
#         'firstName': 'Miranda',
#         'lastName': 'Maverick',
#         'slug': 'miranda-maverick-12226',
#         'nationality': 'United States'},
#        'order': 11,
#        'weightClass': {'weightClass': 'Flyweight',
#         'weight': 125,
#         'id': 'V2VpZ2h0Q2xhc3NOb2RlOjM='},
#        'isCancelled': False,
#        'fightType': 'PL',
#        'methodOfVictory1': 'Decision',
#        'methodOfVictory2': 'Unanimous',
#        'round': 3,
#        'duration': '5:00',
#        'slug': 'miranda-maverick-vs-jamey-lyn-horth-57481',
#        'pk': 57481,
#        'fighter1Odds': -750,
#        'fighter2Odds': 550}},
#      {'node': {'id': 'RmlnaHROb2RlOjU2NzY4',
#        'fighter1': {'id': 'RmlnaHRlck5vZGU6NjAyOA==',
#         'pk': 6028,
#         'firstName': 'Davey',
#         'lastName': 'Grant',
#         'slug': 'davey-grant-6028',
#         'nationality': 'Bishop Auckland, England'},
#        'fighter2': {'id': 'RmlnaHRlck5vZGU6NTQ4NDY=',
#         'pk': 54846,
#         'firstName': 'Ramon',
#         'lastName': 'Taveras',
#         'slug': 'ramon-taveras-54846',
#         'nationality': 'United States'},
#        'fighterWinner': {'id': 'RmlnaHRlck5vZGU6NjAyOA==',
#         'pk': 6028,
#         'firstName': 'Davey',
#         'lastName': 'Grant',
#         'slug': 'davey-grant-6028',
#         'nationality': 'Bishop Auckland, England'},
#        'order': 12,
#        'weightClass': {'weightClass': 'Bantamweight',
#         'weight': 135,
#         'id': 'V2VpZ2h0Q2xhc3NOb2RlOjQ='},
#        'isCancelled': False,
#        'fightType': 'PL',
#        'methodOfVictory1': 'Decision',
#        'methodOfVictory2': 'Unanimous',
#        'round': 3,
#        'duration': '5:00',
#        'slug': 'davey-grant-vs-ramon-taveras-56768',
#        'pk': 56768,
#        'fighter1Odds': -116,
#        'fighter2Odds': -104}},
#      {'node': {'id': 'RmlnaHROb2RlOjU2MzIy',
#        'fighter1': {'id': 'RmlnaHRlck5vZGU6Mzk0NTE=',
#         'pk': 39451,
#         'firstName': 'Piera',
#         'lastName': 'Rodriguez',
#         'slug': 'piera-rodriguez-39451',
#         'nationality': 'Venezuela'},
#        'fighter2': {'id': 'RmlnaHRlck5vZGU6Mzc0MjQ=',
#         'pk': 37424,
#         'firstName': 'Josefine',
#         'lastName': 'Knutsson',
#         'slug': 'josefine-knutsson-37424',
#         'nationality': 'Bromma, Sweden'},
#        'fighterWinner': {'id': 'RmlnaHRlck5vZGU6Mzk0NTE=',
#         'pk': 39451,
#         'firstName': 'Piera',
#         'lastName': 'Rodriguez',
#         'slug': 'piera-rodriguez-39451',
#         'nationality': 'Venezuela'},
#        'order': 13,
#        'weightClass': {'weightClass': 'Strawweight',
#         'weight': 115,
#         'id': 'V2VpZ2h0Q2xhc3NOb2RlOjI='},
#        'isCancelled': False,
#        'fightType': 'PL',
#        'methodOfVictory1': 'Decision',
#        'methodOfVictory2': 'Unanimous',
#        'round': 3,
#        'duration': '5:00',
#        'slug': 'piera-rodriguez-vs-josefine-knutsson-56322',
#        'pk': 56322,
#        'fighter1Odds': 230,
#        'fighter2Odds': -270}},
#      {'node': {'id': 'RmlnaHROb2RlOjU3Mzkz',
#        'fighter1': {'id': 'RmlnaHRlck5vZGU6MjkzNzY=',
#         'pk': 29376,
#         'firstName': 'Ian',
#         'lastName': 'Garry',
#         'slug': 'ian-garry-29376',
#         'nationality': 'Ireland'},
#        'fighter2': {'id': 'RmlnaHRlck5vZGU6ODk5Mw==',
#         'pk': 8993,
#         'firstName': 'Joaquin',
#         'lastName': 'Buckley',
#         'slug': 'joaquin-buckley-8993',
#         'nationality': 'United States'},
#        'fighterWinner': None,
#        'order': 1,
#        'weightClass': {'weightClass': 'Welterweight',
#         'weight': 170,
#         'id': 'V2VpZ2h0Q2xhc3NOb2RlOjc='},
#        'isCancelled': True,
#        'fightType': 'ME',
#        'methodOfVictory1': '',
#        'methodOfVictory2': '',
#        'round': None,
#        'duration': '',
#        'slug': 'ian-garry-vs-joaquin-buckley-57393',
#        'pk': 57393,
#        'fighter1Odds': -225,
#        'fighter2Odds': 190}},
#      {'node': {'id': 'RmlnaHROb2RlOjU2MDg4',
#        'fighter1': {'id': 'RmlnaHRlck5vZGU6MTc4OTM=',
#         'pk': 17893,
#         'firstName': 'Amanda',
#         'lastName': 'Ribas',
#         'slug': 'amanda-ribas-17893',
#         'nationality': 'Brazil'},
#        'fighter2': {'id': 'RmlnaHRlck5vZGU6OTE0MQ==',
#         'pk': 9141,
#         'firstName': 'Mackenzie',
#         'lastName': 'Dern',
#         'slug': 'mackenzie-dern-9141',
#         'nationality': 'United States'},
#        'fighterWinner': None,
#        'order': 2,
#        'weightClass': {'weightClass': 'Strawweight',
#         'weight': 115,
#         'id': 'V2VpZ2h0Q2xhc3NOb2RlOjI='},
#        'isCancelled': True,
#        'fightType': 'CO',
#        'methodOfVictory1': '',
#        'methodOfVictory2': '',
#        'round': None,
#        'duration': '',
#        'slug': 'amanda-ribas-vs-mackenzie-dern-56088',
#        'pk': 56088,
#        'fighter1Odds': -175,
#        'fighter2Odds': 150}},
#      {'node': {'id': 'RmlnaHROb2RlOjU3MjU4',
#        'fighter1': {'id': 'RmlnaHRlck5vZGU6MTY2NjU=',
#         'pk': 16665,
#         'firstName': 'Said',
#         'lastName': 'Nurmagomedov',
#         'slug': 'said-nurmagomedov-16665',
#         'nationality': 'Russia'},
#        'fighter2': {'id': 'RmlnaHRlck5vZGU6Mzg5MTU=',
#         'pk': 38915,
#         'firstName': 'Daniel',
#         'lastName': 'Marcos',
#         'slug': 'daniel-marcos-38915',
#         'nationality': 'Peru'},
#        'fighterWinner': None,
#        'order': 3,
#        'weightClass': {'weightClass': 'Bantamweight',
#         'weight': 135,
#         'id': 'V2VpZ2h0Q2xhc3NOb2RlOjQ='},
#        'isCancelled': True,
#        'fightType': 'MC',
#        'methodOfVictory1': '',
#        'methodOfVictory2': '',
#        'round': None,
#        'duration': '',
#        'slug': 'said-nurmagomedov-vs-daniel-marcos-57258',
#        'pk': 57258,
#        'fighter1Odds': None,
#        'fighter2Odds': None}},
#      {'node': {'id': 'RmlnaHROb2RlOjU2MjUy',
#        'fighter1': {'id': 'RmlnaHRlck5vZGU6MTIyMjY=',
#         'pk': 12226,
#         'firstName': 'Miranda',
#         'lastName': 'Maverick',
#         'slug': 'miranda-maverick-12226',
#         'nationality': 'United States'},
#        'fighter2': {'id': 'RmlnaHRlck5vZGU6MTcyMDY=',
#         'pk': 17206,
#         'firstName': 'Tracy',
#         'lastName': 'Cortez',
#         'slug': 'tracy-cortez-17206',
#         'nationality': 'Phoenix, Arizona'},
#        'fighterWinner': None,
#        'order': 4,
#        'weightClass': {'weightClass': 'Flyweight',
#         'weight': 125,
#         'id': 'V2VpZ2h0Q2xhc3NOb2RlOjM='},
#        'isCancelled': True,
#        'fightType': 'MC',
#        'methodOfVictory1': '',
#        'methodOfVictory2': '',
#        'round': None,
#        'duration': '',
#        'slug': 'miranda-maverick-vs-tracy-cortez-56252',
#        'pk': 56252,
#        'fighter1Odds': None,
#        'fighter2Odds': None}}]},
#    'id': 'RXZlbnROb2RlOjU5Mzk='}}}

# %%
FIGHTER_QUERY = """
query FighterQuery(
  $fighterSlug: String
) {
  fighter: fighterBySlug(slug: $fighterSlug) {
    ...FighterTabPanelInfo_fighter
    id
  }
}

fragment FighterTabPanelInfo_fighter on FighterNode {
  ...FighterTableInfo_fighter
  ...FighterTableFightingStyle_fighter
}

fragment FighterTableFightingStyle_fighter on FighterNode {
  stance
}

fragment FighterTableInfo_fighter on FighterNode {
  id
  pk
  slug
  firstName
  lastName
  nickName
  birthDate
  nationality
  height
  reach
  legReach
  fightingStyle
}
"""

payload = json.dumps(
    {
        "query": FIGHTER_QUERY,
        "variables": {
        "fighterSlug": "joaquin-buckley-8993"
        },
    }
)
response = requests.post(url=url, headers=headers, data=payload)
json_resp = response.json()
json_resp
# Out:
# {'data': {'fighter': {'id': 'RmlnaHRlck5vZGU6ODk5Mw==',
#    'pk': 8993,
#    'slug': 'joaquin-buckley-8993',
#    'firstName': 'Joaquin',
#    'lastName': 'Buckley',
#    'nickName': 'New Mansa',
#    'birthDate': '1994-04-27',
#    'nationality': 'United States',
#    'height': '178.0',
#    'reach': '76.0',
#    'legReach': '0.0',
#    'fightingStyle': 'Striker',
#    'stance': 'Southpaw'}}}

# %%
FIGHT_PROP_OFFERS_TABLE_QUERY = """
query FightPropOfferTableQrQuery(
  $fightSlug: String!
) {
  sportsbooks: allSportsbooks(hasOdds: true) {
    ...FightPropOfferTable_sportsbooks
  }
  fightPropOfferTable(slug: $fightSlug) {
    ...FightPropOfferTable_fightPropOfferTable
    id
  }
  offerTypes: allOfferTypes {
    ...FightPropOfferTable_offerTypes
  }
}

fragment FightPropOfferTable_fightPropOfferTable on FightPropOfferTableNode {
  propOffers {
    edges {
      node {
        propName1
        propName2
        bestOdds1
        bestOdds2
        offerType {
          id
        }
        offers {
          edges {
            node {
              sportsbook {
                id
              }
              outcome1 {
                id
                odds
                ...OddsWithArrowButton_outcome
              }
              outcome2 {
                id
                odds
                ...OddsWithArrowButton_outcome
              }
              id
            }
          }
        }
      }
    }
  }
}

fragment FightPropOfferTable_offerTypes on OfferTypeNodeConnection {
  edges {
    node {
      id
    }
  }
}

fragment FightPropOfferTable_sportsbooks on SportsbookNodeConnection {
  edges {
    node {
      id
      slug
      shortName
      fullName
      websiteUrl
    }
  }
}

fragment OddsWithArrowButton_outcome on OutcomeNode {
  id
  ...OddsWithArrow_outcome
}

fragment OddsWithArrow_outcome on OutcomeNode {
  odds
  oddsPrev
}
"""

payload = json.dumps(
    {
        "query": FIGHT_PROP_OFFERS_TABLE_QUERY,
        "variables": {
        "fightSlug": "colby-covington-vs-joaquin-buckley-57616"
        },
    }
)
response = requests.post(url=url, headers=headers, data=payload)
json_resp = response.json()
json_resp
# Out:
# {'data': {'sportsbooks': {'edges': [{'node': {'id': 'U3BvcnRzYm9va05vZGU6Mjg=',
#       'slug': 'betus',
#       'shortName': 'BetUS',
#       'fullName': 'BetUS',
#       'websiteUrl': 'https://www.betus.com.pa/'}},
#     {'node': {'id': 'U3BvcnRzYm9va05vZGU6Mg==',
#       'slug': 'bookmaker',
#       'shortName': 'Bookmaker',
#       'fullName': 'Bookmaker',
#       'websiteUrl': 'http://www.bookmaker.eu/'}},
#     {'node': {'id': 'U3BvcnRzYm9va05vZGU6NDI=',
#       'slug': 'bet105',
#       'shortName': 'Bet105',
#       'fullName': 'Bet105',
#       'websiteUrl': 'https://bet105.eu/en'}},
#     {'node': {'id': 'U3BvcnRzYm9va05vZGU6Mzg=',
#       'slug': '4casters',
#       'shortName': '4casters',
#       'fullName': '4casters',
#       'websiteUrl': 'https://4casters.io/'}},
#     {'node': {'id': 'U3BvcnRzYm9va05vZGU6MzU=',
#       'slug': 'betrivers',
#       'shortName': 'BetRivers',
#       'fullName': 'BetRivers',
#       'websiteUrl': 'https://www.betrivers.com/'}},
#     {'node': {'id': 'U3BvcnRzYm9va05vZGU6MjU=',
#       'slug': 'betanysports',
#       'shortName': 'BetAnySports',
#       'fullName': 'BetAnySports',
#       'websiteUrl': 'https://betanysports.eu/'}},
#     {'node': {'id': 'U3BvcnRzYm9va05vZGU6MjA=',
#       'slug': 'jazz-sports',
#       'shortName': 'Jazz',
#       'fullName': 'Jazz Sports',
#       'websiteUrl': 'https://jazzsports.ag/'}},
#     {'node': {'id': 'U3BvcnRzYm9va05vZGU6MTc=',
#       'slug': 'cloudbet',
#       'shortName': 'Cloudbet',
#       'fullName': 'Cloudbet',
#       'websiteUrl': 'https://www.cloudbet.com/en/'}},
#     {'node': {'id': 'U3BvcnRzYm9va05vZGU6NA==',
#       'slug': 'bovada',
#       'shortName': 'Bovada',
#       'fullName': 'Bovada',
#       'websiteUrl': 'http://www.bovada.lv/'}},
#     {'node': {'id': 'U3BvcnRzYm9va05vZGU6MzM=',
#       'slug': 'betmgm',
#       'shortName': 'BetMGM',
#       'fullName': 'BetMGM',
#       'websiteUrl': 'https://betmgm.com'}},
#     {'node': {'id': 'U3BvcnRzYm9va05vZGU6Mjk=',
#       'slug': 'sx-bet',
#       'shortName': 'SXBet',
#       'fullName': 'SX Bet',
#       'websiteUrl': 'https://sx.bet/'}},
#     {'node': {'id': 'U3BvcnRzYm9va05vZGU6MjE=',
#       'slug': 'mybookie',
#       'shortName': 'MyBookie',
#       'fullName': 'MyBookie',
#       'websiteUrl': 'https://mybookie.ag/'}},
#     {'node': {'id': 'U3BvcnRzYm9va05vZGU6MzQ=',
#       'slug': 'caesars-sportsbook',
#       'shortName': 'Caesars',
#       'fullName': 'Caesars Sportsbook',
#       'websiteUrl': 'https://www.caesars.com/sportsbook-and-casino'}},
#     {'node': {'id': 'U3BvcnRzYm9va05vZGU6OA==',
#       'slug': 'pinnacle-sports',
#       'shortName': 'Pinnacle',
#       'fullName': 'Pinnacle Sports',
#       'websiteUrl': 'http://www.pinnacle.com/'}},
#     {'node': {'id': 'U3BvcnRzYm9va05vZGU6MjM=',
#       'slug': 'fanduel',
#       'shortName': 'FanDuel',
#       'fullName': 'FanDuel',
#       'websiteUrl': 'https://sportsbook.fanduel.com/'}},
#     {'node': {'id': 'U3BvcnRzYm9va05vZGU6MTA=',
#       'slug': 'betonline',
#       'shortName': 'BetOnline',
#       'fullName': 'BetOnline',
#       'websiteUrl': 'https://www.betonline.ag/'}},
#     {'node': {'id': 'U3BvcnRzYm9va05vZGU6Mjc=',
#       'slug': 'betway',
#       'shortName': 'Betway',
#       'fullName': 'Betway',
#       'websiteUrl': 'https://betway.com'}},
#     {'node': {'id': 'U3BvcnRzYm9va05vZGU6MjQ=',
#       'slug': 'draftkings',
#       'shortName': 'DraftKings',
#       'fullName': 'DraftKings',
#       'websiteUrl': 'https://sportsbook.draftkings.com/'}}]},
#   'fightPropOfferTable': {'propOffers': {'edges': [{'node': {'propName1': 'Colby Covington',
#        'propName2': 'Joaquin Buckley',
#        'bestOdds1': 500,
#        'bestOdds2': -205,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZTox'},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MjE='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA4MTY0NQ==',
#             'odds': 175,
#             'oddsPrev': 183},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA4MTY0NA==',
#             'odds': -220,
#             'oddsPrev': -230},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxNzc4Mjc='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MTA='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA4NjQwNA==',
#             'odds': 190,
#             'oddsPrev': 180},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA4NjQwMw==',
#             'odds': -225,
#             'oddsPrev': -210},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODEwNjA='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MTc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA4NzQ0OQ==',
#             'odds': 200,
#             'oddsPrev': 199},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA4NzQ0OA==',
#             'odds': -225,
#             'oddsPrev': -235},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODE5MzA='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6OA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA4NzMyNw==',
#             'odds': 200,
#             'oddsPrev': 195},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA4NzMyNg==',
#             'odds': -233,
#             'oddsPrev': -227},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODE4Mjk='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA4MjE2Ng==',
#             'odds': 190,
#             'oddsPrev': 185},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA4MjE2Nw==',
#             'odds': -225,
#             'oddsPrev': -220},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxNzgyMTY='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MjM='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA4MTE5MA==',
#             'odds': 172,
#             'oddsPrev': 190},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA4MTE5MQ==',
#             'odds': -205,
#             'oddsPrev': -230},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxNzc0OTI='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjg='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NzE0NQ==',
#             'odds': 185,
#             'oddsPrev': None},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NzE0Ng==',
#             'odds': -225,
#             'oddsPrev': None},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg5MTI='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MzU='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA4MTY0Mg==',
#             'odds': 170,
#             'oddsPrev': 205},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA4MTY0Mw==',
#             'odds': -215,
#             'oddsPrev': -265},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxNzc4MjY='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjg='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NzEzOQ==',
#             'odds': 170,
#             'oddsPrev': None},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NzE0MA==',
#             'odds': -205,
#             'oddsPrev': -210},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg5MDk='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MjU='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NzEyOA==',
#             'odds': 180,
#             'oddsPrev': 205},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NzEyNw==',
#             'odds': -220,
#             'oddsPrev': -215},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg5MDM='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MzQ='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA4MjYwOA==',
#             'odds': 180,
#             'oddsPrev': 190},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA4MjYwOQ==',
#             'odds': -220,
#             'oddsPrev': -230},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxNzg1MDk='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjg='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NzA5Mw==',
#             'odds': 181,
#             'oddsPrev': 180},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NzA5NA==',
#             'odds': -221,
#             'oddsPrev': -220},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg4ODY='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MzM='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA4NTU5Nw==',
#             'odds': 175,
#             'oddsPrev': 185},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA4NTU5OA==',
#             'odds': -210,
#             'oddsPrev': -225},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODA1MjU='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjg='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5Njk4Mw==',
#             'odds': 180,
#             'oddsPrev': None},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5Njk4NA==',
#             'odds': -220,
#             'oddsPrev': None},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg4MzE='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MjE='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NzE1Mg==',
#             'odds': 170,
#             'oddsPrev': None},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NzE1MQ==',
#             'odds': -250,
#             'oddsPrev': None},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg5MTU='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA4Mzk2NQ==',
#             'odds': 235,
#             'oddsPrev': 300},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA4Mzk2Ng==',
#             'odds': -357,
#             'oddsPrev': -500},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxNzk2MDM='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjg='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA4ODE2NA==',
#             'odds': 180,
#             'oddsPrev': 165},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA4ODE2NQ==',
#             'odds': -220,
#             'oddsPrev': -200},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODIzMjA='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MjA='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA4ODIzNw==',
#             'odds': 186,
#             'oddsPrev': 182},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA4ODIzNg==',
#             'odds': -232,
#             'oddsPrev': -226},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODIzNTY='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mg=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA4OTQ1Mw==',
#             'odds': 186,
#             'oddsPrev': 180},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA4OTQ1Mg==',
#             'odds': -233,
#             'oddsPrev': -225},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODMzMjM='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mzg='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA4OTQ1MA==',
#             'odds': 201,
#             'oddsPrev': 199},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA4OTQ1MQ==',
#             'odds': -219,
#             'oddsPrev': -220},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODMzMjI='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NDI='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5MTI4NQ==',
#             'odds': 193,
#             'oddsPrev': 194},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5MTI4Ng==',
#             'odds': -224,
#             'oddsPrev': -225},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODQ3NDQ='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MjQ='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NzE0OQ==',
#             'odds': 500,
#             'oddsPrev': 200},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NzE1MA==',
#             'odds': -810,
#             'oddsPrev': -270},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg5MTQ='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjk='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5MzczNw==',
#             'odds': 192,
#             'oddsPrev': 174},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5MzczOA==',
#             'odds': -245,
#             'oddsPrev': -236},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY0NzY='}}]}}},
#      {'node': {'propName1': 'Fight ends in a Draw',
#        'propName2': "Fight doesn't end in a Draw",
#        'bestOdds1': 6600,
#        'bestOdds2': 0,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToy'},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NDEyMQ==',
#             'odds': 5000,
#             'oddsPrev': None},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY3MjI='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MTA='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5MzIwNw==',
#             'odds': 6600,
#             'oddsPrev': None},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODU5OTA='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjM3Ng==',
#             'odds': 5000,
#             'oddsPrev': None},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg0NDU='}}]}}},
#      {'node': {'propName1': 'Over 1.5 rounds',
#        'propName2': 'Under 1.5 rounds',
#        'bestOdds1': -649,
#        'bestOdds2': 400,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToyMw=='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzc1OQ==',
#             'odds': -650,
#             'oddsPrev': -550},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzc2MA==',
#             'odds': 400,
#             'oddsPrev': 350},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY0ODc='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NDEwNw==',
#             'odds': -649,
#             'oddsPrev': None},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NDEwOA==',
#             'odds': 400,
#             'oddsPrev': None},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY3MTI='}}]}}},
#      {'node': {'propName1': 'Over 2.5 rounds',
#        'propName2': 'Under 2.5 rounds',
#        'bestOdds1': -333,
#        'bestOdds2': 250,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToyNA=='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NDEwOQ==',
#             'odds': -333,
#             'oddsPrev': None},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NDExMA==',
#             'odds': 225,
#             'oddsPrev': None},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY3MTM='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzc2MQ==',
#             'odds': -350,
#             'oddsPrev': -300},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzc2Mg==',
#             'odds': 250,
#             'oddsPrev': 220},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY0ODg='}}]}}},
#      {'node': {'propName1': 'Over 3.5 rounds',
#        'propName2': 'Under 3.5 rounds',
#        'bestOdds1': -220,
#        'bestOdds2': 165,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToyNQ=='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzc2Mw==',
#             'odds': -220,
#             'oddsPrev': -190},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzc2NA==',
#             'odds': 165,
#             'oddsPrev': 145},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY0ODk='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NDExMQ==',
#             'odds': -225,
#             'oddsPrev': None},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NDExMg==',
#             'odds': 163,
#             'oddsPrev': None},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY3MTQ='}}]}}},
#      {'node': {'propName1': 'Over 4.5 rounds',
#        'propName2': 'Under 4.5 rounds',
#        'bestOdds1': -140,
#        'bestOdds2': 135,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToyNg=='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6OA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzg4OQ==',
#             'odds': -156,
#             'oddsPrev': -134},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzg5MA==',
#             'odds': 132,
#             'oddsPrev': 114},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY1Nzc='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjg='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NzE0Nw==',
#             'odds': -145,
#             'oddsPrev': None},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NzE0OA==',
#             'odds': 115,
#             'oddsPrev': None},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg5MTM='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NDI='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzg2OQ==',
#             'odds': -155,
#             'oddsPrev': -156},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzg3MA==',
#             'odds': 131,
#             'oddsPrev': 132},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY1Njc='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5MzAyMQ==',
#             'odds': -155,
#             'oddsPrev': -165},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5MzAyMg==',
#             'odds': 120,
#             'oddsPrev': 125},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODU4OTQ='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjg='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5Njk4NQ==',
#             'odds': -150,
#             'oddsPrev': None},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5Njk4Ng==',
#             'odds': 120,
#             'oddsPrev': None},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg4MzI='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MTA='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5MzAxMw==',
#             'odds': -160,
#             'oddsPrev': -155},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5MzAxNA==',
#             'odds': 130,
#             'oddsPrev': 125},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODU4OTA='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MjE='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5MzEzNw==',
#             'odds': -140,
#             'oddsPrev': -134},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5MzEzOA==',
#             'odds': 110,
#             'oddsPrev': 106},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODU5NTI='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjg='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NzA5NQ==',
#             'odds': -150,
#             'oddsPrev': None},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NzA5Ng==',
#             'odds': 120,
#             'oddsPrev': None},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg4ODc='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjg='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NzE0MQ==',
#             'odds': -165,
#             'oddsPrev': -145},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NzE0Mg==',
#             'odds': 135,
#             'oddsPrev': 115},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg5MTA='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MjQ='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzg1OQ==',
#             'odds': -145,
#             'oddsPrev': -160},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzg2MA==',
#             'odds': 114,
#             'oddsPrev': 124},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY1NTk='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NDExMw==',
#             'odds': -150,
#             'oddsPrev': None},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NDExNA==',
#             'odds': 110,
#             'oddsPrev': None},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY3MTU='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MTc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5MzExMQ==',
#             'odds': -152,
#             'oddsPrev': -157},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5MzExMg==',
#             'odds': 133,
#             'oddsPrev': 131},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODU5Mzk='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjg='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5MzA4OQ==',
#             'odds': -150,
#             'oddsPrev': -155},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5MzA5MA==',
#             'odds': 120,
#             'oddsPrev': 125},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODU5Mjg='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjk='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjcwMw==',
#             'odds': -163,
#             'oddsPrev': -158},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NjcwNA==',
#             'odds': 126,
#             'oddsPrev': 127},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg2ODc='}}]}}},
#      {'node': {'propName1': 'Fight ends in No Contest via Eye Poke',
#        'propName2': 'Any other result',
#        'bestOdds1': 0,
#        'bestOdds2': 5000,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToxNjM='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': None,
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NjQwNw==',
#             'odds': 5000,
#             'oddsPrev': None},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg0NzY='}}]}}},
#      {'node': {'propName1': 'Fight ends in No Contest via Illegal Knee',
#        'propName2': 'Any other result',
#        'bestOdds1': 0,
#        'bestOdds2': 5000,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToxNjQ='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': None,
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NjQwOA==',
#             'odds': 5000,
#             'oddsPrev': None},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg0Nzc='}}]}}},
#      {'node': {'propName1': 'Both fighters to be Knocked Down',
#        'propName2': 'Any other result',
#        'bestOdds1': 700,
#        'bestOdds2': 0,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToxNzM='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjQyMw==',
#             'odds': 700,
#             'oddsPrev': None},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg0OTI='}}]}}},
#      {'node': {'propName1': 'Point Deduction',
#        'propName2': 'No Point Deduction',
#        'bestOdds1': 1600,
#        'bestOdds2': 0,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToxNzU='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjQyNQ==',
#             'odds': 1600,
#             'oddsPrev': -100000},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg0OTQ='}}]}}},
#      {'node': {'propName1': 'Takedowns landed - Tie',
#        'propName2': 'Any other result',
#        'bestOdds1': 300,
#        'bestOdds2': 0,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToxNzQ='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjQyNA==',
#             'odds': 300,
#             'oddsPrev': None},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg0OTM='}}]}}},
#      {'node': {'propName1': 'Fight goes the distance',
#        'propName2': 'Fight ends inside distance',
#        'bestOdds1': -115,
#        'bestOdds2': 105,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToz'},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5MzcyNw==',
#             'odds': -115,
#             'oddsPrev': -130},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5MzcyOA==',
#             'odds': -115,
#             'oddsPrev': 100},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY0NzE='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MTA='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5MzE4Mw==',
#             'odds': -115,
#             'oddsPrev': -125},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5MzE4NA==',
#             'odds': -115,
#             'oddsPrev': -105},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODU5NzU='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MjQ='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzg2MQ==',
#             'odds': -120,
#             'oddsPrev': -135},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzg2Mg==',
#             'odds': -110,
#             'oddsPrev': 100},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY1NjA='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MjE='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTAyMg==',
#             'odds': -119,
#             'oddsPrev': -115},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NTAyMw==',
#             'odds': -112,
#             'oddsPrev': -115},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODczOTQ='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NDEyOA==',
#             'odds': -125,
#             'oddsPrev': -138},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NDEyOQ==',
#             'odds': -105,
#             'oddsPrev': -100},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY3Mjk='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6OA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjA1OA==',
#             'odds': -120,
#             'oddsPrev': -124},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NjA1OQ==',
#             'odds': -111,
#             'oddsPrev': -107},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODgyODQ='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MTc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5MzkzOQ==',
#             'odds': -123,
#             'oddsPrev': -115},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzk0MA==',
#             'odds': 105,
#             'oddsPrev': -102},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY2MDg='}}]}}},
#      {'node': {'propName1': 'Fight starts round 2',
#        'propName2': "Fight doesn't start round 2",
#        'bestOdds1': -800,
#        'bestOdds2': 650,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZTo3'},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MTA='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjQ5Nw==',
#             'odds': -800,
#             'oddsPrev': -700},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NjQ5OA==',
#             'odds': 500,
#             'oddsPrev': 450},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg1MzE='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NDkzOA==',
#             'odds': -1200,
#             'oddsPrev': -1000},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NDkzOQ==',
#             'odds': 650,
#             'oddsPrev': 550},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODczMzI='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6OA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjA2OA==',
#             'odds': -1165,
#             'oddsPrev': -950},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NjA2OQ==',
#             'odds': 572,
#             'oddsPrev': 505},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODgyODk='}}]}}},
#      {'node': {'propName1': 'Fight starts round 3',
#        'propName2': "Fight doesn't start round 3",
#        'bestOdds1': -385,
#        'bestOdds2': 369,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZTo2'},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6OA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjA4OA==',
#             'odds': -599,
#             'oddsPrev': -356},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NjA4OQ==',
#             'odds': 369,
#             'oddsPrev': 246},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODgyOTk='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MTA='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjQ5OQ==',
#             'odds': -400,
#             'oddsPrev': None},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NjUwMA==',
#             'odds': 300,
#             'oddsPrev': None},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg1MzI='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NDkzNg==',
#             'odds': -385,
#             'oddsPrev': -375},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NDkzNw==',
#             'odds': 265,
#             'oddsPrev': 260},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODczMzE='}}]}}},
#      {'node': {'propName1': 'Fight starts round 4',
#        'propName2': "Fight doesn't start round 4",
#        'bestOdds1': -216,
#        'bestOdds2': 200,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZTo1'},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MTA='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjUwMQ==',
#             'odds': -260,
#             'oddsPrev': None},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NjUwMg==',
#             'odds': 200,
#             'oddsPrev': None},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg1MzM='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NDkzMg==',
#             'odds': -240,
#             'oddsPrev': -260},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NDkzMw==',
#             'odds': 180,
#             'oddsPrev': 190},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODczMjk='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6OA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjA4NA==',
#             'odds': -216,
#             'oddsPrev': None},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NjA4NQ==',
#             'odds': 165,
#             'oddsPrev': None},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODgyOTc='}}]}}},
#      {'node': {'propName1': 'Fight starts round 5',
#        'propName2': "Fight doesn't start round 5",
#        'bestOdds1': -145,
#        'bestOdds2': 145,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZTo0'},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NDkzNA==',
#             'odds': -145,
#             'oddsPrev': -155},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NDkzNQ==',
#             'odds': 110,
#             'oddsPrev': 120},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODczMzA='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6OA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjA1NA==',
#             'odds': -155,
#             'oddsPrev': -154},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NjA1NQ==',
#             'odds': 116,
#             'oddsPrev': 120},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODgyODI='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MTA='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjUwMw==',
#             'odds': -175,
#             'oddsPrev': None},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NjUwNA==',
#             'odds': 145,
#             'oddsPrev': 125},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg1MzQ='}}]}}},
#      {'node': {'propName1': 'Fight ends in round 1',
#        'propName2': "Fight doesn't end in round 1",
#        'bestOdds1': 650,
#        'bestOdds2': 0,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZTozMw=='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NDE0Mw==',
#             'odds': 500,
#             'oddsPrev': 600},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY3Mzk='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTU5MQ==',
#             'odds': 650,
#             'oddsPrev': 550},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODc5Mzc='}}]}}},
#      {'node': {'propName1': 'Fight ends in round 2',
#        'propName2': "Fight doesn't end in round 2",
#        'bestOdds1': 700,
#        'bestOdds2': 0,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZTozNA=='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTU5Mg==',
#             'odds': 700,
#             'oddsPrev': 600},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODc5Mzg='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NDE0NA==',
#             'odds': 700,
#             'oddsPrev': 800},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY3NDA='}}]}}},
#      {'node': {'propName1': 'Fight ends in round 3',
#        'propName2': "Fight doesn't end in round 3",
#        'bestOdds1': 850,
#        'bestOdds2': 0,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZTozNQ=='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NDE0NQ==',
#             'odds': 850,
#             'oddsPrev': 1000},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY3NDE='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTU5Mw==',
#             'odds': 800,
#             'oddsPrev': None},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODc5Mzk='}}]}}},
#      {'node': {'propName1': 'Fight ends in round 4',
#        'propName2': "Fight doesn't end in round 4",
#        'bestOdds1': 1000,
#        'bestOdds2': 0,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZTozNg=='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTU5NA==',
#             'odds': 900,
#             'oddsPrev': 1000},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODc5NDA='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NDE0Ng==',
#             'odds': 1000,
#             'oddsPrev': 1200},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY3NDI='}}]}}},
#      {'node': {'propName1': 'Fight ends in round 5',
#        'propName2': "Fight doesn't end in round 5",
#        'bestOdds1': 1200,
#        'bestOdds2': 0,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZTozNw=='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTU5NQ==',
#             'odds': 1200,
#             'oddsPrev': 1400},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODc5NDE='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NDE0Nw==',
#             'odds': 1200,
#             'oddsPrev': 1600},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY3NDM='}}]}}},
#      {'node': {'propName1': 'Fight ends by KO, TKO or DQ',
#        'propName2': "Fight doesn't end by KO, TKO or DQ",
#        'bestOdds1': 110,
#        'bestOdds2': 0,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToxNDA='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTU4OA==',
#             'odds': 110,
#             'oddsPrev': None},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODc5MzQ='}}]}}},
#      {'node': {'propName1': 'Fight ends in split or majority decision',
#        'propName2': "Fight doesn't end in split or majority decision",
#        'bestOdds1': 450,
#        'bestOdds2': -700,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToxNDQ='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MTA='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5MzI0NQ==',
#             'odds': 450,
#             'oddsPrev': 400},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5MzI0Ng==',
#             'odds': -700,
#             'oddsPrev': 425},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODYwMjc='}}]}}},
#      {'node': {'propName1': 'Fight ends in submission',
#        'propName2': "Fight doesn't end in submission",
#        'bestOdds1': 1000,
#        'bestOdds2': 0,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToxNDE='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTU4OQ==',
#             'odds': 1000,
#             'oddsPrev': None},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODc5MzU='}}]}}},
#      {'node': {'propName1': 'Covington wins inside distance',
#        'propName2': "Covington doesn't win inside distance",
#        'bestOdds1': 800,
#        'bestOdds2': -1587,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZTo4'},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NDEzNA==',
#             'odds': 700,
#             'oddsPrev': None},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NDEzNQ==',
#             'odds': -1587,
#             'oddsPrev': None},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY3MzI='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6OA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjA3NA==',
#             'odds': 762,
#             'oddsPrev': 815},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NjA3NQ==',
#             'odds': -2064,
#             'oddsPrev': -2430},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODgyOTI='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MTA='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5MzI0MA==',
#             'odds': 750,
#             'oddsPrev': 825},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODYwMjI='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTIyNA==',
#             'odds': 800,
#             'oddsPrev': 850},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODc1ODk='}}]}}},
#      {'node': {'propName1': 'Buckley wins inside distance',
#        'propName2': "Buckley doesn't win inside distance",
#        'bestOdds1': 140,
#        'bestOdds2': -133,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZTo4'},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTIyNg==',
#             'odds': 130,
#             'oddsPrev': None},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODc1OTE='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MTA='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5MzI0MQ==',
#             'odds': 110,
#             'oddsPrev': 120},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODYwMjM='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NDEzNg==',
#             'odds': 140,
#             'oddsPrev': None},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NDEzNw==',
#             'odds': -188,
#             'oddsPrev': None},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY3MzM='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6OA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjA2MA==',
#             'odds': 101,
#             'oddsPrev': 112},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NjA2MQ==',
#             'odds': -133,
#             'oddsPrev': -149},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODgyODU='}}]}}},
#      {'node': {'propName1': 'Covington wins by decision',
#        'propName2': "Covington doesn't win by decision",
#        'bestOdds1': 315,
#        'bestOdds2': -400,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZTo5'},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6OA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjA1Mg==',
#             'odds': 274,
#             'oddsPrev': 285},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NjA1Mw==',
#             'odds': -406,
#             'oddsPrev': -426},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODgyODE='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MTA='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5MzIwMQ==',
#             'odds': 260,
#             'oddsPrev': 275},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODU5ODQ='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NDEzMA==',
#             'odds': 275,
#             'oddsPrev': 300},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NDEzMQ==',
#             'odds': -400,
#             'oddsPrev': -450},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY3MzA='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTIyNQ==',
#             'odds': 315,
#             'oddsPrev': 350},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODc1OTA='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTIxNA==',
#             'odds': 315,
#             'oddsPrev': 350},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODc1Nzk='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MjE='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzk3MQ==',
#             'odds': 260,
#             'oddsPrev': 280},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY2MzM='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MjQ='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzg2Nw==',
#             'odds': 300,
#             'oddsPrev': 330},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY1NjU='}}]}}},
#      {'node': {'propName1': 'Buckley wins by decision',
#        'propName2': "Buckley doesn't win by decision",
#        'bestOdds1': 201,
#        'bestOdds2': -200,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZTo5'},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NDEzMg==',
#             'odds': 150,
#             'oddsPrev': None},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NDEzMw==',
#             'odds': -200,
#             'oddsPrev': None},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY3MzE='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTIxNw==',
#             'odds': 175,
#             'oddsPrev': None},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODc1ODI='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MTc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzk1Mw==',
#             'odds': 201,
#             'oddsPrev': 208},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY2MjE='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MjE='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzk3NA==',
#             'odds': 160,
#             'oddsPrev': 161},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY2MzY='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MjQ='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzg2OA==',
#             'odds': 200,
#             'oddsPrev': 175},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY1NjY='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MTA='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5MzIwNA==',
#             'odds': 200,
#             'oddsPrev': 175},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODU5ODc='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6OA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjA2Ng==',
#             'odds': 166,
#             'oddsPrev': 201},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NjA2Nw==',
#             'odds': -226,
#             'oddsPrev': -281},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODgyODg='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTIyNw==',
#             'odds': 175,
#             'oddsPrev': None},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODc1OTI='}}]}}},
#      {'node': {'propName1': 'Covington wins by TKO/KO',
#        'propName2': "Covington doesn't win by TKO/KO",
#        'bestOdds1': 1400,
#        'bestOdds2': -6843,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToxMA=='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTIxMg==',
#             'odds': 1400,
#             'oddsPrev': None},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODc1Nzc='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NDEzOA==',
#             'odds': 1000,
#             'oddsPrev': 800},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY3MzQ='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MTA='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5MzIwMg==',
#             'odds': 1200,
#             'oddsPrev': 1000},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODU5ODU='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MjQ='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzg2Mw==',
#             'odds': 1100,
#             'oddsPrev': 1400},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY1NjE='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MjE='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5Mzk2OQ==',
#             'odds': 940,
#             'oddsPrev': 910},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODY2MzE='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6OA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjA1MA==',
#             'odds': 1088,
#             'oddsPrev': 1100},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NjA1MQ==',
#             'odds': -6843,
#             'oddsPrev': -2207},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODgyODA='}}]}}},
#      {'node': {'propName1': 'Buckley wins by TKO/KO',
#        'propName2': "Buckley doesn't win by TKO/KO",
#        'bestOdds1': 196,
# ...
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjQxNg==',
#             'odds': 110,
#             'oddsPrev': None},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg0ODU='}}]}}},
#      {'node': {'propName1': 'Buckley most Significant Strikes Landed in Round 4',
#        'propName2': 'Buckley Any other result',
#        'bestOdds1': -150,
#        'bestOdds2': 0,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToxNzE='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjQyMQ==',
#             'odds': -150,
#             'oddsPrev': None},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg0OTA='}}]}}},
#      {'node': {'propName1': 'Covington most Significant Strikes Landed in Round 5',
#        'propName2': 'Covington Any other result',
#        'bestOdds1': 110,
#        'bestOdds2': 0,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToxNzI='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjQxNw==',
#             'odds': 110,
#             'oddsPrev': None},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg0ODY='}}]}}},
#      {'node': {'propName1': 'Buckley most Significant Strikes Landed in Round 5',
#        'propName2': 'Buckley Any other result',
#        'bestOdds1': -150,
#        'bestOdds2': 0,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToxNzI='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6Mjc='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NjQyMg==',
#             'odds': -150,
#             'oddsPrev': None},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODg0OTE='}}]}}},
#      {'node': {'propName1': 'Covington wins by Submission or Decision',
#        'propName2': 'Covington Any other result',
#        'bestOdds1': 300,
#        'bestOdds2': 0,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToxODM='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTIxOQ==',
#             'odds': 300,
#             'oddsPrev': 265},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODc1ODQ='}}]}}},
#      {'node': {'propName1': 'Buckley wins by Submission or Decision',
#        'propName2': 'Buckley Any other result',
#        'bestOdds1': 150,
#        'bestOdds2': 0,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToxODM='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTIyMg==',
#             'odds': 150,
#             'oddsPrev': 140},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODc1ODc='}}]}}},
#      {'node': {'propName1': 'Covington wins by KO/TKO or Decision',
#        'propName2': 'Covington Any other result',
#        'bestOdds1': 250,
#        'bestOdds2': 0,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToxODI='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTIyMA==',
#             'odds': 250,
#             'oddsPrev': 240},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODc1ODU='}}]}}},
#      {'node': {'propName1': 'Buckley wins by KO/TKO or Decision',
#        'propName2': 'Buckley Any other result',
#        'bestOdds1': -275,
#        'bestOdds2': 0,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToxODI='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTIyMw==',
#             'odds': -275,
#             'oddsPrev': None},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODc1ODg='}}]}}},
#      {'node': {'propName1': 'Covington wins by KO/TKO or Submission',
#        'propName2': 'Covington Any other result',
#        'bestOdds1': 800,
#        'bestOdds2': 0,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToxODQ='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTIxOA==',
#             'odds': 800,
#             'oddsPrev': 850},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODc1ODM='}}]}}},
#      {'node': {'propName1': 'Buckley wins by KO/TKO or Submission',
#        'propName2': 'Buckley Any other result',
#        'bestOdds1': 130,
#        'bestOdds2': 0,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToxODQ='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTIyMQ==',
#             'odds': 130,
#             'oddsPrev': None},
#            'outcome2': None,
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODc1ODY='}}]}}},
#      {'node': {'propName1': 'Colby Covington (scorecards = no action)',
#        'propName2': 'Joaquin Buckley (scorecards = no action)',
#        'bestOdds1': 375,
#        'bestOdds2': -450,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZTo5OA=='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6MTA='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5MzIzOA==',
#             'odds': 325,
#             'oddsPrev': 300},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5MzIzOQ==',
#             'odds': -450,
#             'oddsPrev': -400},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODYwMjE='}},
#          {'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTk5Ng==',
#             'odds': 375,
#             'oddsPrev': 425},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NTk5Nw==',
#             'odds': -600,
#             'oddsPrev': -700},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODgyNTM='}}]}}},
#      {'node': {'propName1': 'Colby Covington 5.5',
#        'propName2': 'Joaquin Buckley -5.5',
#        'bestOdds1': -135,
#        'bestOdds2': 105,
#        'offerType': {'id': 'T2ZmZXJUeXBlTm9kZToxOA=='},
#        'offers': {'edges': [{'node': {'sportsbook': {'id': 'U3BvcnRzYm9va05vZGU6NA=='},
#            'outcome1': {'id': 'T3V0Y29tZU5vZGU6NjA5NTk4MA==',
#             'odds': -135,
#             'oddsPrev': -115},
#            'outcome2': {'id': 'T3V0Y29tZU5vZGU6NjA5NTk4MQ==',
#             'odds': 105,
#             'oddsPrev': -115},
#            'id': 'T2ZmZXJUYWJsZU9mZmVyTm9kZToxMDMxODgyNDU='}}]}}}]},
#    'id': 'RmlnaHRQcm9wT2ZmZXJUYWJsZU5vZGU6NTc2MTY='},
#   'offerTypes': {'edges': [{'node': {'id': 'T2ZmZXJUeXBlTm9kZTox'}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNTY='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToy'}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMTE='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToyMw=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToyNA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToyNQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToyNg=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToz'}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo3'}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo2'}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo1'}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo0'}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTozMw=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTozNA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTozNQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTozNg=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTozNw=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNTM='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNTI='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNTE='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNDg='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNDk='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNTQ='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNDU='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNDA='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNTA='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNDY='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNDc='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNDQ='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNDE='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNDM='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMjY='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMjk='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMjQ='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMjg='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMjU='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMjM='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMjI='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMjc='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMTk='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMTY='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMTc='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMTg='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNDI='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMjE='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMjA='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTozMg=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNjQ='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNjM='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNzQ='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNzM='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNzU='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNzk='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxODA='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxODE='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxODY='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo4'}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo5'}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMg=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMw=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToyNw=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToyOA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToyOQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTozMA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTozMQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMzE='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMzc='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMzA='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMzg='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMzU='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMzI='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMzY='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMzk='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMzM='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMzQ='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo5Mg=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo5Mw=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo5NQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo5MQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo5NA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMTI='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMTM='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMTQ='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMTU='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTozOA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTozOQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNTc='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNjE='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNTg='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNjA='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNjI='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNTk='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNjU='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNjY='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNzA='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNjk='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNjc='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNzI='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNzE='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxODM='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxODI='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxODQ='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxODU='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo3Mg=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo0MA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo1Ng=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo0MQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo1Nw=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo3Mw=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo0OQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo2NQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo4MQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo1OA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo0Mg=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo3NA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo4Mg=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo1MA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo2Ng=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo0Mw=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo3NQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo1OQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo4Mw=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo1MQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo2Nw=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo3Ng=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo2MA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo0NA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo2OA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo4NA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo1Mg=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo0NQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo2MQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo3Nw=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo4NQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo1Mw=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo2OQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo2Mg=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo0Ng=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo3OA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo3MA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo4Ng=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo1NA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo3OQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo2Mw=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo0Nw=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo1NQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo3MQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo4Nw=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo2NA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo0OA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo4MA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMDE='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMDM='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo5OQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMDQ='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMDI='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMDA='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMDk='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMDc='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMDU='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMDY='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMDg='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxMTA='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNTU='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo5OA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNzg='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNzc='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNzY='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNg=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxNw=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxOA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToxOQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToyMA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToyMQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZToyMg=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo4OA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo4OQ=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo5MA=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo5Ng=='}},
#     {'node': {'id': 'T2ZmZXJUeXBlTm9kZTo5Nw=='}}]}}}

# %%
FIGHT_ODDS_QUERY = """
query FightOddsQuery(
  $fightSlug: String
) {
  sportsbooks: allSportsbooks(hasOdds: true) {
    ...FightTabPanelOdds_sportsbooks
  }
  fightOfferTable(slug: $fightSlug) {
    ...FightTabPanelOdds_fightOfferTable
    id
  }
  outcomes: fightOutcomesTable(slug: $fightSlug) {
    ...FightTabPanelOdds_outcomes
  }
  fight: fightBySlug(slug: $fightSlug) {
    ...FightTabPanelOdds_fight
    id
  }
}

fragment FightExpectedOutcomesTable_fight on FightNode {
  fighter1 {
    pk
    lastName
    id
  }
  fighter2 {
    pk
    lastName
    id
  }
}

fragment FightExpectedOutcomesTable_outcomes on FightOutcomeNodeConnection {
  edges {
    node {
      offerTypeId
      isNot
      avgOdds
      fighterPk
      description
      notDescription
    }
  }
}

fragment FightOfferTable_fightOfferTable on FightOfferTableNode {
  slug
  fighter1 {
    firstName
    lastName
    id
  }
  fighter2 {
    firstName
    lastName
    id
  }
  bestOdds1
  bestOdds2
  straightOffers {
    edges {
      node {
        sportsbook {
          id
          shortName
          slug
        }
        outcome1 {
          id
          odds
          oddsOpen
          oddsBest
          oddsWorst
          ...OddsWithArrowButton_outcome
        }
        outcome2 {
          id
          odds
          oddsOpen
          oddsBest
          oddsWorst
          ...OddsWithArrowButton_outcome
        }
        id
      }
    }
  }
}

fragment FightOfferTable_sportsbooks on SportsbookNodeConnection {
  edges {
    node {
      id
      slug
      shortName
      fullName
      websiteUrl
    }
  }
}

fragment FightTabPanelOdds_fight on FightNode {
  ...FightExpectedOutcomesTable_fight
}

fragment FightTabPanelOdds_fightOfferTable on FightOfferTableNode {
  ...FightOfferTable_fightOfferTable
  propCount
  slug
}

fragment FightTabPanelOdds_outcomes on FightOutcomeNodeConnection {
  ...FightExpectedOutcomesTable_outcomes
}

fragment FightTabPanelOdds_sportsbooks on SportsbookNodeConnection {
  ...FightOfferTable_sportsbooks
}

fragment OddsWithArrowButton_outcome on OutcomeNode {
  id
  ...OddsWithArrow_outcome
}

fragment OddsWithArrow_outcome on OutcomeNode {
  odds
  oddsPrev
}
"""

payload = json.dumps(
    {
        "query": FIGHT_ODDS_QUERY,
        "variables": {
        "fightSlug": "colby-covington-vs-joaquin-buckley-57616"
        },
    }
)
response = requests.post(url=url, headers=headers, data=payload)
json_resp = response.json()
json_resp
# Out:
# {'errors': [{'message': 'Cannot query field "pk" on type "SportsbookNode".',
#    'locations': [{'line': 95, 'column': 7}]}]}
