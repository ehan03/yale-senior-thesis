# %%
import os
import sqlite3

import pandas as pd

db_path = os.path.join(os.path.dirname("__file__"), "..", "..", "data", "ufc.db")

# %% [markdown]
# ### Find bouts where both fighters have fought at least once in UFC

# %%
query = """
WITH cte1 AS (
    SELECT fighter_id, t1.'order', bout_id FROM ufcstats_fighter_histories t1
    INNER JOIN bout_mapping t2 ON t1.bout_id = t2.ufcstats_id
),
cte2 AS (
    SELECT fighter_id, bout_id, ROW_NUMBER() OVER (PARTITION BY fighter_id ORDER BY t1.'order') AS ufc_order FROM cte1 t1
),
cte3 AS (
    SELECT
        id,
        t3.ufc_order AS red_ufc_order,
        t4.ufc_order AS blue_ufc_order
    FROM ufcstats_bouts t1
    INNER JOIN bout_mapping t2 ON t1.id = t2.ufcstats_id
    LEFT JOIN cte2 t3 ON t1.id = t3.bout_id AND t1.red_fighter_id = t3.fighter_id
    LEFT JOIN cte2 t4 ON t1.id = t4.bout_id AND t1.blue_fighter_id = t4.fighter_id
)
SELECT id FROM cte3 WHERE
    red_ufc_order > 1 AND blue_ufc_order > 1
"""

with sqlite3.connect(db_path) as conn:
    query_res = pd.read_sql_query(query, conn)
exp_level_bout_ids = query_res["id"].tolist()

# %% [markdown]
# ### Filter for only men's bouts where both fighters have fought at least once in UFC

# %%
features_df = pd.read_pickle("../../data/features.pkl.xz", compression="xz")
features_df
# Out:
#                     id  avg_knockdowns_scored_diff  \
# 0     be38ed9ccfe2ee03                    0.000000
# 1     eb1b371dfc37fcdb                    0.000000
# 2     219bd976b8ca745d                    0.000000
# 3     af178adff964d854                    0.200000
# 4     920194911d727a38                    0.000000
# ...                ...                         ...
# 7071  5238f6470d0557fb                    0.250000
# 7072  7b1bc4ff776f12c1                   -0.085714
# 7073  1a635a5e4551e7d5                   -0.142857
# 7074  7521015554088962                    0.175000
# 7075  00c6a2ef07ca51da                   -0.580357
#
#       cumulative_knockdowns_scored_diff  \
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                     1
# 4                                     1
# ...                                 ...
# 7071                                  4
# 7072                                 -3
# 7073                                 -1
# 7074                                  7
# 7075                                 -8
#
#       avg_knockdowns_scored_per_second_diff  \
# 0                                  0.000000
# 1                                  0.000000
# 2                                  0.000000
# 3                                  0.000313
# 4                                  0.000000
# ...                                     ...
# 7071                               0.001888
# 7072                              -0.001594
# 7073                              -0.001952
# 7074                               0.000810
# 7075                              -0.001161
#
#       cumulative_knockdowns_scored_per_second_diff  \
# 0                                         0.000000
# 1                                         0.000000
# 2                                         0.000000
# 3                                         0.000430
# 4                                         0.000000
# ...                                            ...
# 7071                                      0.001181
# 7072                                     -0.000143
# 7073                                     -0.000514
# 7074                                      0.000208
# 7075                                     -0.000972
#
#       avg_knockdowns_scored_per_strike_landed_diff  \
# 0                                         0.000000
# 1                                         0.000000
# 2                                         0.000000
# 3                                         0.002247
# 4                                         0.000000
# ...                                            ...
# 7071                                      0.015227
# 7072                                     -0.004453
# 7073                                     -0.023014
# 7074                                      0.010541
# 7075                                     -0.015009
#
#       cumulative_knockdowns_scored_per_strike_landed_diff  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.004386
# 4                                              0.000000
# ...                                                 ...
# 7071                                           0.010821
# 7072                                           0.000881
# 7073                                          -0.007278
# 7074                                           0.003426
# 7075                                          -0.012277
#
#       avg_knockdowns_scored_per_strike_attempted_diff  \
# 0                                            0.000000
# 1                                            0.000000
# 2                                            0.000000
# 3                                            0.001639
# 4                                            0.000000
# ...                                               ...
# 7071                                         0.006283
# 7072                                        -0.003147
# 7073                                        -0.010774
# 7074                                         0.005460
# 7075                                        -0.005432
#
#       cumulative_knockdowns_scored_per_strike_attempted_diff  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.000000
# 3                                              0.003115
# 4                                              0.000000
# ...                                                 ...
# 7071                                           0.003462
# 7072                                           0.000704
# 7073                                          -0.004009
# 7074                                           0.001763
# 7075                                          -0.004804
#
#       avg_knockdowns_scored_per_significant_strike_landed_diff  ...  \
# 0                                              0.000000         ...
# 1                                              0.000000         ...
# 2                                              0.000000         ...
# 3                                              0.004651         ...
# 4                                              0.000000         ...
# ...                                                 ...         ...
# 7071                                           0.015179         ...
# 7072                                           0.006262         ...
# 7073                                          -0.028357         ...
# 7074                                           0.010358         ...
# 7075                                          -0.015208         ...
#
#       avg_opp_event_attendance_change_diff  \
# 0                             -3611.000000
# 1                                 0.000000
# 2                              5791.250000
# 3                             -5569.000000
# 4                                 0.000000
# ...                                    ...
# 7071                          -4734.666667
# 7072                         -18745.000000
# 7073                          -8795.333333
# 7074                           3649.085714
# 7075                          -2166.642857
#
#       avg_opp_event_attendance_change_diff_diff  \
# 0                                   6580.500000
# 1                                      0.000000
# 2                                      0.000000
# 3                                      0.000000
# 4                                      0.000000
# ...                                         ...
# 7071                               11243.000000
# 7072                                   0.000000
# 7073                               -1100.500000
# 7074                               -4911.654135
# 7075                                1257.736264
#
#       avg_opp_avg_event_attendance_change_diff  \
# 0                                   206.916667
# 1                                     0.000000
# 2                                  2043.861111
# 3                                     0.000000
# 4                                 -4205.666667
# ...                                        ...
# 7071                                722.184292
# 7072                                 82.594036
# 7073                              -3269.043056
# 7074                               1349.485978
# 7075                               2918.615291
#
#       avg_opp_avg_event_attendance_change_diff_diff  \
# 0                                       7790.250000
# 1                                          0.000000
# 2                                     -10063.500000
# 3                                          0.000000
# 4                                          0.000000
# ...                                             ...
# 7071                                   -1511.853896
# 7072                                    4943.723440
# 7073                                   20082.425000
# 7074                                    1308.150105
# 7075                                   -2952.042057
#
#       avg_opp_avg_event_occupancy_pct_diff  \
# 0                                -0.001338
# 1                                 0.000000
# 2                                -0.097682
# 3                                -0.237066
# 4                                -0.112834
# ...                                    ...
# 7071                             -0.202461
# 7072                              0.039104
# 7073                              0.167921
# 7074                              0.138067
# 7075                              0.146279
#
#       avg_opp_avg_event_occupancy_pct_diff_diff  \
# 0                                     -0.316345
# 1                                      0.000000
# 2                                     -0.516345
# 3                                      0.000000
# 4                                      0.000000
# ...                                         ...
# 7071                                  -0.584005
# 7072                                   0.251747
# 7073                                  -0.258702
# 7074                                   0.222074
# 7075                                   0.351576
#
#       avg_opp_event_occupancy_pct_change_diff  \
# 0                                   -0.167808
# 1                                    0.000000
# 2                                   -0.102990
# 3                                    0.000000
# 4                                   -0.346601
# ...                                       ...
# 7071                                 0.000000
# 7072                                -0.224510
# 7073                                -0.320822
# 7074                                -0.297118
# 7075                                 0.349310
#
#       avg_opp_event_occupancy_pct_change_diff_diff  \
# 0                                         0.596338
# 1                                         0.000000
# 2                                        -0.649139
# 3                                         0.000000
# 4                                         0.000000
# ...                                            ...
# 7071                                      0.000000
# 7072                                      0.421001
# 7073                                      0.585316
# 7074                                      0.372520
# 7075                                     -0.564538
#
#       avg_opp_avg_event_occupancy_pct_change_diff  \
# 0                                       -0.008228
# 1                                        0.000000
# 2                                        0.073671
# 3                                        0.000000
# 4                                        0.080951
# ...                                           ...
# 7071                                     0.007550
# 7072                                     0.035729
# 7073                                    -0.161427
# 7074                                     0.084494
# 7075                                     0.132261
#
#       avg_opp_avg_event_occupancy_pct_change_diff_diff
# 0                                             0.201749
# 1                                             0.000000
# 2                                            -0.509056
# 3                                             0.000000
# 4                                             0.000000
# ...                                                ...
# 7071                                          0.173006
# 7072                                          0.306498
# 7073                                          0.579691
# 7074                                          0.042074
# 7075                                         -0.091775
#
# [7076 rows x 3906 columns]

# %%
features_case_study = features_df.loc[(features_df["id"].isin(exp_level_bout_ids)) & (features_df["is_female"] == 0)].copy().reset_index(drop=True)
features_case_study
# Out:
#                     id  avg_knockdowns_scored_diff  \
# 0     be38ed9ccfe2ee03                    0.000000
# 1     219bd976b8ca745d                    0.000000
# 2     af178adff964d854                    0.200000
# 3     96da5813683649f5                   -0.200000
# 4     df3b75809b7fe252                    0.000000
# ...                ...                         ...
# 4834  5238f6470d0557fb                    0.250000
# 4835  7b1bc4ff776f12c1                   -0.085714
# 4836  1a635a5e4551e7d5                   -0.142857
# 4837  7521015554088962                    0.175000
# 4838  00c6a2ef07ca51da                   -0.580357
#
#       cumulative_knockdowns_scored_diff  \
# 0                                     0
# 1                                     0
# 2                                     1
# 3                                    -1
# 4                                     0
# ...                                 ...
# 4834                                  4
# 4835                                 -3
# 4836                                 -1
# 4837                                  7
# 4838                                 -8
#
#       avg_knockdowns_scored_per_second_diff  \
# 0                                  0.000000
# 1                                  0.000000
# 2                                  0.000313
# 3                                 -0.000222
# 4                                  0.000000
# ...                                     ...
# 4834                               0.001888
# 4835                              -0.001594
# 4836                              -0.001952
# 4837                               0.000810
# 4838                              -0.001161
#
#       cumulative_knockdowns_scored_per_second_diff  \
# 0                                         0.000000
# 1                                         0.000000
# 2                                         0.000430
# 3                                        -0.000269
# 4                                         0.000000
# ...                                            ...
# 4834                                      0.001181
# 4835                                     -0.000143
# 4836                                     -0.000514
# 4837                                      0.000208
# 4838                                     -0.000972
#
#       avg_knockdowns_scored_per_strike_landed_diff  \
# 0                                         0.000000
# 1                                         0.000000
# 2                                         0.002247
# 3                                        -0.002817
# 4                                         0.000000
# ...                                            ...
# 4834                                      0.015227
# 4835                                     -0.004453
# 4836                                     -0.023014
# 4837                                      0.010541
# 4838                                     -0.015009
#
#       cumulative_knockdowns_scored_per_strike_landed_diff  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.004386
# 3                                             -0.006024
# 4                                              0.000000
# ...                                                 ...
# 4834                                           0.010821
# 4835                                           0.000881
# 4836                                          -0.007278
# 4837                                           0.003426
# 4838                                          -0.012277
#
#       avg_knockdowns_scored_per_strike_attempted_diff  \
# 0                                            0.000000
# 1                                            0.000000
# 2                                            0.001639
# 3                                           -0.001600
# 4                                            0.000000
# ...                                               ...
# 4834                                         0.006283
# 4835                                        -0.003147
# 4836                                        -0.010774
# 4837                                         0.005460
# 4838                                        -0.005432
#
#       cumulative_knockdowns_scored_per_strike_attempted_diff  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                              0.003115
# 3                                             -0.003846
# 4                                              0.000000
# ...                                                 ...
# 4834                                           0.003462
# 4835                                           0.000704
# 4836                                          -0.004009
# 4837                                           0.001763
# 4838                                          -0.004804
#
#       avg_knockdowns_scored_per_significant_strike_landed_diff  ...  \
# 0                                              0.000000         ...
# 1                                              0.000000         ...
# 2                                              0.004651         ...
# 3                                             -0.007692         ...
# 4                                              0.000000         ...
# ...                                                 ...         ...
# 4834                                           0.015179         ...
# 4835                                           0.006262         ...
# 4836                                          -0.028357         ...
# 4837                                           0.010358         ...
# 4838                                          -0.015208         ...
#
#       avg_opp_event_attendance_change_diff  \
# 0                             -3611.000000
# 1                              5791.250000
# 2                             -5569.000000
# 3                              1661.466667
# 4                                 0.000000
# ...                                    ...
# 4834                          -4734.666667
# 4835                         -18745.000000
# 4836                          -8795.333333
# 4837                           3649.085714
# 4838                          -2166.642857
#
#       avg_opp_event_attendance_change_diff_diff  \
# 0                                   6580.500000
# 1                                      0.000000
# 2                                      0.000000
# 3                                  -1201.000000
# 4                                      0.000000
# ...                                         ...
# 4834                               11243.000000
# 4835                                   0.000000
# 4836                               -1100.500000
# 4837                               -4911.654135
# 4838                                1257.736264
#
#       avg_opp_avg_event_attendance_change_diff  \
# 0                                   206.916667
# 1                                  2043.861111
# 2                                     0.000000
# 3                                    23.208333
# 4                                     0.000000
# ...                                        ...
# 4834                                722.184292
# 4835                                 82.594036
# 4836                              -3269.043056
# 4837                               1349.485978
# 4838                               2918.615291
#
#       avg_opp_avg_event_attendance_change_diff_diff  \
# 0                                       7790.250000
# 1                                     -10063.500000
# 2                                          0.000000
# 3                                       5164.013889
# 4                                          0.000000
# ...                                             ...
# 4834                                   -1511.853896
# 4835                                    4943.723440
# 4836                                   20082.425000
# 4837                                    1308.150105
# 4838                                   -2952.042057
#
#       avg_opp_avg_event_occupancy_pct_diff  \
# 0                                -0.001338
# 1                                -0.097682
# 2                                -0.237066
# 3                                -0.216629
# 4                                -0.310681
# ...                                    ...
# 4834                             -0.202461
# 4835                              0.039104
# 4836                              0.167921
# 4837                              0.138067
# 4838                              0.146279
#
#       avg_opp_avg_event_occupancy_pct_diff_diff  \
# 0                                     -0.316345
# 1                                     -0.516345
# 2                                      0.000000
# 3                                      0.107524
# 4                                      0.000000
# ...                                         ...
# 4834                                  -0.584005
# 4835                                   0.251747
# 4836                                  -0.258702
# 4837                                   0.222074
# 4838                                   0.351576
#
#       avg_opp_event_occupancy_pct_change_diff  \
# 0                                   -0.167808
# 1                                   -0.102990
# 2                                    0.000000
# 3                                    0.202652
# 4                                    0.000000
# ...                                       ...
# 4834                                 0.000000
# 4835                                -0.224510
# 4836                                -0.320822
# 4837                                -0.297118
# 4838                                 0.349310
#
#       avg_opp_event_occupancy_pct_change_diff_diff  \
# 0                                         0.596338
# 1                                        -0.649139
# 2                                         0.000000
# 3                                        -0.021123
# 4                                         0.000000
# ...                                            ...
# 4834                                      0.000000
# 4835                                      0.421001
# 4836                                      0.585316
# 4837                                      0.372520
# 4838                                     -0.564538
#
#       avg_opp_avg_event_occupancy_pct_change_diff  \
# 0                                       -0.008228
# 1                                        0.073671
# 2                                        0.000000
# 3                                        0.002736
# 4                                        0.000000
# ...                                           ...
# 4834                                     0.007550
# 4835                                     0.035729
# 4836                                    -0.161427
# 4837                                     0.084494
# 4838                                     0.132261
#
#       avg_opp_avg_event_occupancy_pct_change_diff_diff
# 0                                             0.201749
# 1                                            -0.509056
# 2                                             0.000000
# 3                                             0.031342
# 4                                             0.000000
# ...                                                ...
# 4834                                          0.173006
# 4835                                          0.306498
# 4836                                          0.579691
# 4837                                          0.042074
# 4838                                         -0.091775
#
# [4839 rows x 3906 columns]

# %%
features_case_study.to_pickle("../../data/features_case_study.pkl.xz", compression="xz")

# %%
backtest_odds_df = pd.read_csv("../../data/backtesting/backtest_odds.csv")
backtest_odds_case_study = backtest_odds_df.loc[backtest_odds_df["bout_id"].isin(features_case_study["id"])].copy().reset_index(drop=True)
backtest_odds_case_study
# Out:
#                bout_id          event_id        date sportsbook  red_odds  \
# 0     c1356395d6b055d7  46effbd1135423c5  2017-01-15     Bovada      -110
# 1     ae803440d778a12b  46effbd1135423c5  2017-01-15     Bovada       190
# 2     3f7684492c9df05e  46effbd1135423c5  2017-01-15     Bovada      -160
# 3     8156479490877d08  46effbd1135423c5  2017-01-15     Bovada      -170
# 4     1a81573425c585fb  46effbd1135423c5  2017-01-15     Bovada      -145
# ...                ...               ...         ...        ...       ...
# 2617  5238f6470d0557fb  72c9c2eadfc3277e  2024-12-14     Bovada       215
# 2618  7b1bc4ff776f12c1  72c9c2eadfc3277e  2024-12-14     Bovada      -320
# 2619  1a635a5e4551e7d5  72c9c2eadfc3277e  2024-12-14     Bovada      -420
# 2620  7521015554088962  72c9c2eadfc3277e  2024-12-14     Bovada       175
# 2621  00c6a2ef07ca51da  72c9c2eadfc3277e  2024-12-14     Bovada       190
#
#       blue_odds  red_win
# 0          -120      0.0
# 1          -240      0.0
# 2           130      1.0
# 3           140      1.0
# 4           115      1.0
# ...         ...      ...
# 2617       -260      0.0
# 2618        265      0.0
# 2619        320      1.0
# 2620       -205      1.0
# 2621       -225      0.0
#
# [2622 rows x 7 columns]

# %%
backtest_odds_case_study.to_csv("../../data/backtesting/backtest_odds_case_study.csv", index=False)
