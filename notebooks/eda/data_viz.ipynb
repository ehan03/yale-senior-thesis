# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="darkgrid", context="poster")

# %%
features_df = pd.read_pickle("../../data/features.pkl.xz")
features_df
# Out:
#                     id  avg_knockdowns_scored_diff  \
# 0     be38ed9ccfe2ee03                    0.000000
# 1     eb1b371dfc37fcdb                    0.000000
# 2     219bd976b8ca745d                    0.000000
# 3     af178adff964d854                    0.200000
# 4     920194911d727a38                    0.000000
# ...                ...                         ...
# 7071  5238f6470d0557fb                    0.250000
# 7072  7b1bc4ff776f12c1                   -0.085714
# 7073  1a635a5e4551e7d5                   -0.142857
# 7074  7521015554088962                    0.175000
# 7075  00c6a2ef07ca51da                   -0.580357
#
#       cumulative_knockdowns_scored_diff  \
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                     1
# 4                                     1
# ...                                 ...
# 7071                                  4
# ...

# %%
subset = features_df.loc[features_df["red_win"].notnull()].copy()
subset["red_win"] = subset["red_win"].astype(int)
subset
# Out:
#                     id  avg_knockdowns_scored_diff  \
# 0     be38ed9ccfe2ee03                    0.000000
# 1     eb1b371dfc37fcdb                    0.000000
# 2     219bd976b8ca745d                    0.000000
# 3     af178adff964d854                    0.200000
# 4     920194911d727a38                    0.000000
# ...                ...                         ...
# 7071  5238f6470d0557fb                    0.250000
# 7072  7b1bc4ff776f12c1                   -0.085714
# 7073  1a635a5e4551e7d5                   -0.142857
# 7074  7521015554088962                    0.175000
# 7075  00c6a2ef07ca51da                   -0.580357
#
#       cumulative_knockdowns_scored_diff  \
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                     1
# 4                                     1
# ...                                 ...
# 7071                                  4
# ...

# %%
subset["cumulative_significant_strikes_landed_per_second_diff"]
# Out:
# 0       0.001013
# 1       0.000000
# 2       0.032298
# 3       0.027272
# 4       0.000000
#           ...
# 7071    0.005574
# 7072   -0.051397
# 7073    0.018697
# 7074   -0.029693
# 7075   -0.004035
# Name: cumulative_significant_strikes_landed_per_second_diff, Length: 6945, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10, 4))
sns.histplot(data=subset.loc[subset["woe_by_fighting_style_matchup"].abs() <= 2], x="woe_by_fighting_style_matchup", hue="red_win", ax=ax)
ax.set_xlabel("Fighting style matchup weight of evidence")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 4))
sns.histplot(data=subset, x="elo_modified_diff", hue="red_win", ax=ax)
ax.set_xlabel("Difference in modified Elo rating")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 4))
sns.histplot(data=subset, x="age_days_diff", hue="red_win", ax=ax)
ax.set_xlabel("Difference in age in days")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 4))
sns.histplot(data=subset, x="avg_glicko_1_change_diff", hue="red_win", ax=ax)
ax.set_xlabel("Difference in average post-fight Glicko-1 rating change")
plt.show()

# %%
cols = subset.columns
temp = [col for col in cols if "total_time_" in col]
temp
# Out:
# ['total_time_fought_seconds_diff',
#  'avg_opp_total_time_fought_seconds_diff',
#  'avg_total_time_fought_seconds_diff_diff']

# %%
fig, ax = plt.subplots(figsize=(10, 4))
sns.histplot(data=subset, x="avg_total_time_fought_seconds_diff_diff", hue="red_win", ax=ax)
ax.set_xlabel("Difference in average difference in total time fought between fighters and their opponents")
plt.show()

# %%
cols = subset.columns
temp = [col for col in cols if "opening" in col]
temp
# Out:
# ['avg_moneyline_opening_odds_diff',
#  'avg_moneyline_opening_implied_prob_diff',
#  'avg_opp_opening_odds_diff',
#  'avg_opp_opening_implied_prob_diff',
#  'mean_devigged_opening_implied_prob_diff']

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.histplot(data=subset, x="mean_devigged_opening_implied_prob_diff", hue="red_win", ax=ax, bins=50)
ax.set_xlabel("Difference in mean devigged opening implied probability")
plt.show()
